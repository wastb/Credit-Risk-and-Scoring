# %% [markdown]
# #### ***Feature Engineering and Encoding***
#
# *Feature engineering is the process of using domain knowledge to select, modify, or create features (input variables) that enhance the performance of machine learning models.*
# *It involves transforming raw data into a format that is better suited for predictive modeling. This can include:*
# 1. *Creating new features: Combining or transforming existing features to create new ones that capture relevant information.*
# 2. *Selecting features: Choosing a subset of relevant features from a larger set to improve model performance and reduce complexity.*
# 3. *Transforming features: Modifying features to meet the assumptions of a model, such as normalizing data or encoding categorical variables.*

# %%
##Import libraries

import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
## Load the cleaned dataset

df = pd.read_csv("../data/cleaned_data.csv")
df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId    ProviderId     ProductId     ProductCategory  \
# 0  CustomerId_4406  ProviderId_6  ProductId_10             airtime
# 1  CustomerId_4406  ProviderId_4   ProductId_6  financial_services
# 2  CustomerId_4683  ProviderId_6   ProductId_1             airtime
# 3   CustomerId_988  ProviderId_1  ProductId_21        utility_bill
# 4   CustomerId_988  ProviderId_4   ProductId_6  financial_services
#
#      ChannelId  Amount   Value  TransactionStartTime  PricingStrategy  \
# 0  ChannelId_3  1000.0  1000.0  2018-11-15T02:18:49Z                2
# 1  ChannelId_2   -20.0    20.0  2018-11-15T02:19:08Z                2
# 2  ChannelId_3   500.0   500.0  2018-11-15T02:44:21Z                2
# 3  ChannelId_3  1000.0  1000.0  2018-11-15T03:32:55Z                2
# 4  ChannelId_2  -644.0   644.0  2018-11-15T03:34:21Z                2
#
#    FraudResult
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# #### ***Aggregate Features***

# %%
# Creating aggregate features

aggregate_features = df.groupby('CustomerId').agg(
    Total_Transaction_Value=('Value', 'sum'),
    Average_Transaction_Value=('Value', 'mean'),
    Transaction_Count=('TransactionId', 'count'),
    Std_Deviation_Transaction_Value=('Value', 'std')
).reset_index()

# Display the aggregate features
aggregate_features
# Out:
#            CustomerId  Total_Transaction_Value  Average_Transaction_Value  \
# 0        CustomerId_1                  10000.0               10000.000000
# 1       CustomerId_10                  10000.0               10000.000000
# 2     CustomerId_1001                  30400.0                6080.000000
# 3     CustomerId_1002                   4775.0                 434.090909
# 4     CustomerId_1003                  32000.0                5333.333333
# ...               ...                      ...                        ...
# 3737   CustomerId_992                  32000.0                5333.333333
# 3738   CustomerId_993                  32000.0                6400.000000
# 3739   CustomerId_994                 225077.0                2228.485149
# 3740   CustomerId_996                 151000.0                8882.352941
# 3741   CustomerId_998                 163000.0                7409.090909
#
#       Transaction_Count  Std_Deviation_Transaction_Value
# 0                     1                              NaN
# 1                     1                              NaN
# 2                     5                      4100.243895
# 3                    11                       518.805446
# 4                     6                      3945.461528
# ...                 ...                              ...
# 3737                  6                      4033.195590
# 3738                  5                      3781.534080
# 3739                101                      3282.616882
# 3740                 17                      2619.216317
# 3741                 22                      3168.431953
#
# [3742 rows x 5 columns]

# %% [markdown]
# #### ***Date Features***

# %%
# Convert TransactionStartTime to datetime
df['TransactionStartTime'] = pd.to_datetime(df['TransactionStartTime'])

# Extracting features
df['Transaction_Hour'] = df['TransactionStartTime'].dt.hour
df['Transaction_Day'] = df['TransactionStartTime'].dt.day
df['Transaction_Month'] = df['TransactionStartTime'].dt.month
df['Transaction_Year'] = df['TransactionStartTime'].dt.year

# Display the updated DataFrame with new features
df[['TransactionId', 'CustomerId', 'Transaction_Hour', 'Transaction_Day', 'Transaction_Month', 'Transaction_Year']]
# Out:
#               TransactionId       CustomerId  Transaction_Hour  \
# 0       TransactionId_76871  CustomerId_4406                 2
# 1       TransactionId_73770  CustomerId_4406                 2
# 2       TransactionId_26203  CustomerId_4683                 2
# 3         TransactionId_380   CustomerId_988                 3
# 4       TransactionId_28195   CustomerId_988                 3
# ...                     ...              ...               ...
# 95657   TransactionId_89881  CustomerId_3078                 9
# 95658   TransactionId_91597  CustomerId_3874                 9
# 95659   TransactionId_82501  CustomerId_3874                 9
# 95660  TransactionId_136354  CustomerId_1709                10
# 95661   TransactionId_35670  CustomerId_1709                10
#
#        Transaction_Day  Transaction_Month  Transaction_Year
# 0                   15                 11              2018
# 1                   15                 11              2018
# 2                   15                 11              2018
# 3                   15                 11              2018
# 4                   15                 11              2018
# ...                ...                ...               ...
# 95657               13                  2              2019
# 95658               13                  2              2019
# 95659               13                  2              2019
# 95660               13                  2              2019
# 95661               13                  2              2019
#
# [95662 rows x 6 columns]

# %% [markdown]
# #### ***Merging Features***

# %%
# Display the final DataFrame with aggregate features and extracted features
final_df = df.merge(aggregate_features, on='CustomerId', how='left')

# Remove the TransactionStartTime column
final_df = final_df.drop(columns=['TransactionStartTime'])

# %%
final_df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId    ProviderId     ProductId     ProductCategory  \
# 0  CustomerId_4406  ProviderId_6  ProductId_10             airtime
# 1  CustomerId_4406  ProviderId_4   ProductId_6  financial_services
# 2  CustomerId_4683  ProviderId_6   ProductId_1             airtime
# 3   CustomerId_988  ProviderId_1  ProductId_21        utility_bill
# 4   CustomerId_988  ProviderId_4   ProductId_6  financial_services
#
#      ChannelId  Amount  ...  PricingStrategy  FraudResult  Transaction_Hour  \
# 0  ChannelId_3  1000.0  ...                2            0                 2
# 1  ChannelId_2   -20.0  ...                2            0                 2
# 2  ChannelId_3   500.0  ...                2            0                 2
# 3  ChannelId_3  1000.0  ...                2            0                 3
# 4  ChannelId_2  -644.0  ...                2            0                 3
#
#    Transaction_Day  Transaction_Month  Transaction_Year  \
# 0               15                 11              2018
# 1               15                 11              2018
# 2               15                 11              2018
# 3               15                 11              2018
# 4               15                 11              2018
#
#    Total_Transaction_Value  Average_Transaction_Value  Transaction_Count  \
# 0                 184847.0                1553.336134                119
# 1                 184847.0                1553.336134                119
# 2                   1000.0                 500.000000                  2
# 3                 117523.0                3092.710526                 38
# 4                 117523.0                3092.710526                 38
#
#    Std_Deviation_Transaction_Value
# 0                      2073.975141
# 1                      2073.975141
# 2                         0.000000
# 3                      3613.003504
# 4                      3613.003504
#
# [5 rows x 21 columns]

# %% [markdown]
# #### ***Removing Unwanted Columns***

# %%
##drop unwanted columns

# List of columns to drop
columns_to_drop = ['BatchId', 'AccountId', 'TransactionId','SubscriptionId', 'ProductId']
final_df.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# #### ***Encoding***

# %%
# One-Hot Encoding
one_hot_columns = ['ProductCategory']
df_one_hot = pd.get_dummies(final_df, columns=one_hot_columns, drop_first=True, dtype=int)

# Display the DataFrame after One-Hot Encoding
df_one_hot.head()
# Out:
#         CustomerId    ProviderId    ChannelId  Amount   Value  \
# 0  CustomerId_4406  ProviderId_6  ChannelId_3  1000.0  1000.0
# 1  CustomerId_4406  ProviderId_4  ChannelId_2   -20.0    20.0
# 2  CustomerId_4683  ProviderId_6  ChannelId_3   500.0   500.0
# 3   CustomerId_988  ProviderId_1  ChannelId_3  1000.0  1000.0
# 4   CustomerId_988  ProviderId_4  ChannelId_2  -644.0   644.0
#
#    PricingStrategy  FraudResult  Transaction_Hour  Transaction_Day  \
# 0                2            0                 2               15
# 1                2            0                 2               15
# 2                2            0                 2               15
# 3                2            0                 3               15
# 4                2            0                 3               15
#
#    Transaction_Month  ...  Transaction_Count  Std_Deviation_Transaction_Value  \
# 0                 11  ...                119                      2073.975141
# 1                 11  ...                119                      2073.975141
# 2                 11  ...                  2                         0.000000
# 3                 11  ...                 38                      3613.003504
# 4                 11  ...                 38                      3613.003504
#
#    ProductCategory_data_bundles  ProductCategory_financial_services  \
# 0                             0                                   0
# 1                             0                                   1
# 2                             0                                   0
# 3                             0                                   0
# 4                             0                                   1
#
#    ProductCategory_movies  ProductCategory_other  ProductCategory_ticket  \
# 0                       0                      0                       0
# 1                       0                      0                       0
# 2                       0                      0                       0
# 3                       0                      0                       0
# 4                       0                      0                       0
#
#    ProductCategory_transport  ProductCategory_tv  ProductCategory_utility_bill
# 0                          0                   0                             0
# 1                          0                   0                             0
# 2                          0                   0                             0
# 3                          0                   0                             1
# 4                          0                   0                             0
#
# [5 rows x 23 columns]

# %%
## Process columns to extract the Id 
columns = ['CustomerId','ProviderId','ChannelId']
for col in columns:
    df_one_hot[col] = df_one_hot[col].str.split('_').str[1]

# %%
df_one_hot.head()
# Out:
#   CustomerId ProviderId ChannelId  Amount   Value  PricingStrategy  \
# 0       4406          6         3  1000.0  1000.0                2
# 1       4406          4         2   -20.0    20.0                2
# 2       4683          6         3   500.0   500.0                2
# 3        988          1         3  1000.0  1000.0                2
# 4        988          4         2  -644.0   644.0                2
#
#    FraudResult  Transaction_Hour  Transaction_Day  Transaction_Month  ...  \
# 0            0                 2               15                 11  ...
# 1            0                 2               15                 11  ...
# 2            0                 2               15                 11  ...
# 3            0                 3               15                 11  ...
# 4            0                 3               15                 11  ...
#
#    Transaction_Count  Std_Deviation_Transaction_Value  \
# 0                119                      2073.975141
# 1                119                      2073.975141
# 2                  2                         0.000000
# 3                 38                      3613.003504
# 4                 38                      3613.003504
#
#    ProductCategory_data_bundles  ProductCategory_financial_services  \
# 0                             0                                   0
# 1                             0                                   1
# 2                             0                                   0
# 3                             0                                   0
# 4                             0                                   1
#
#    ProductCategory_movies  ProductCategory_other  ProductCategory_ticket  \
# 0                       0                      0                       0
# 1                       0                      0                       0
# 2                       0                      0                       0
# 3                       0                      0                       0
# 4                       0                      0                       0
#
#    ProductCategory_transport  ProductCategory_tv  ProductCategory_utility_bill
# 0                          0                   0                             0
# 1                          0                   0                             0
# 2                          0                   0                             0
# 3                          0                   0                             1
# 4                          0                   0                             0
#
# [5 rows x 23 columns]

# %%
df_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   CustomerId                          95662 non-null  object
#  1   ProviderId                          95662 non-null  object
#  2   ChannelId                           95662 non-null  object
#  3   Amount                              95662 non-null  float64
#  4   Value                               95662 non-null  float64
#  5   PricingStrategy                     95662 non-null  int64
#  6   FraudResult                         95662 non-null  int64
#  7   Transaction_Hour                    95662 non-null  int32
#  8   Transaction_Day                     95662 non-null  int32
#  9   Transaction_Month                   95662 non-null  int32
#  10  Transaction_Year                    95662 non-null  int32
#  11  Total_Transaction_Value             95662 non-null  float64
#  12  Average_Transaction_Value           95662 non-null  float64
#  13  Transaction_Count                   95662 non-null  int64
#  14  Std_Deviation_Transaction_Value     94950 non-null  float64
#  15  ProductCategory_data_bundles        95662 non-null  int64
#  16  ProductCategory_financial_services  95662 non-null  int64
#  17  ProductCategory_movies              95662 non-null  int64
#  18  ProductCategory_other               95662 non-null  int64
#  19  ProductCategory_ticket              95662 non-null  int64
#  20  ProductCategory_transport           95662 non-null  int64
#  21  ProductCategory_tv                  95662 non-null  int64
#  22  ProductCategory_utility_bill        95662 non-null  int64
# dtypes: float64(5), int32(4), int64(11), object(3)
# memory usage: 15.3+ MB

# %% [markdown]
# #### ***Handling Missing Values***

# %%
df_one_hot['Std_Deviation_Transaction_Value'] = df_one_hot['Std_Deviation_Transaction_Value'].fillna(0)

# %%
df_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   CustomerId                          95662 non-null  object
#  1   ProviderId                          95662 non-null  object
#  2   ChannelId                           95662 non-null  object
#  3   Amount                              95662 non-null  float64
#  4   Value                               95662 non-null  float64
#  5   PricingStrategy                     95662 non-null  int64
#  6   FraudResult                         95662 non-null  int64
#  7   Transaction_Hour                    95662 non-null  int32
#  8   Transaction_Day                     95662 non-null  int32
#  9   Transaction_Month                   95662 non-null  int32
#  10  Transaction_Year                    95662 non-null  int32
#  11  Total_Transaction_Value             95662 non-null  float64
#  12  Average_Transaction_Value           95662 non-null  float64
#  13  Transaction_Count                   95662 non-null  int64
#  14  Std_Deviation_Transaction_Value     95662 non-null  float64
#  15  ProductCategory_data_bundles        95662 non-null  int64
#  16  ProductCategory_financial_services  95662 non-null  int64
#  17  ProductCategory_movies              95662 non-null  int64
#  18  ProductCategory_other               95662 non-null  int64
#  19  ProductCategory_ticket              95662 non-null  int64
#  20  ProductCategory_transport           95662 non-null  int64
#  21  ProductCategory_tv                  95662 non-null  int64
#  22  ProductCategory_utility_bill        95662 non-null  int64
# dtypes: float64(5), int32(4), int64(11), object(3)
# memory usage: 15.3+ MB

# %%
## Export the data
df_one_hot.to_csv('encoded_data.csv', index=False)
